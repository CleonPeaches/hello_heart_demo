# %% [markdown]
# ## Step 1: Data Ingestion
# Ingest data from the two provided CSV files. One contains patient details, and the other contains appointment data.

# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("hello_heart_data") \
    .getOrCreate()

# Read the CSV files
appointments_df = spark.read.csv('sample_data/appointment_data.csv', header=True, inferSchema=True)
patients_df = spark.read.csv('sample_data/patient_data.csv', header=True, inferSchema=True)

# Get row counts
print(f"\nNumber of appointments: {appointments_df.count()}")
print(f"Number of patients: {patients_df.count()}")

print("\nSample Appointments:")
appointments_df.show(5, truncate=False)

print("\nSample Patients:")
patients_df.show(50, truncate=False)
# Out:
# Number of appointments: 1000
# Number of patients: 1000
#
# Sample Appointments:
# +----------+----------------+--------------+
# |patient_id|appointment_date|doctor        |
# +----------+----------------+--------------+
# |236       |2024-05-17      |Morgan Baker  |
# |225       |2024-08-03      |Vincent Wright|
# |831       |2024-07-19      |Joshua Ford   |
# |116       |2024-03-02      |Michelle Hill |
# |433       |2024-01-17      |Kari Morse    |
# +----------+----------------+--------------+
# only showing top 5 rows
#
#
# Sample Patients:
# +----------+------------------+---+-------------------------------------------------------+---------------------+-------------+
# |patient_id|name              |age|address                                                |phone_number         |diagnosis    |
# +----------+------------------+---+-------------------------------------------------------+---------------------+-------------+
# |1         |Nicole Taylor     |36 |6377 Jennifer Trail Apt. 075, Calebside, NY 22906      |080.898.3247         |Asthma       |
# |2         |Nathan Dorsey     |46 |056 Thompson Park Suite 212, West Anitaport, NY 11534  |001-282-603-2670x455 |Asthma       |
# |3         |Jennifer Garcia   |61 |792 Mark Wells, Jaclynport, TN 90027                   |861-464-2617x287     |Diabetes     |
# |4         |Joshua Simon      |41 |05655 Harris Inlet, Nealton, MS 89986                  |531-269-0179         |Asthma       |
# |5         |Juan Gallegos     |37 |150 Miranda Unions, Bradburgh, FL 64440                |+1-771-958-5462x30717|Asthma       |
# |6         |Dawn Holland      |39 |2523 Flores Radial Suite 462, South Hannah, ND 92740   |+1-134-564-3940x037  |None         |
# |7         |Alan Garrison     |79 |3040 Eddie Bypass, Lake Andrew, RI 07138               |001-582-878-8103x560 |Diabetes     |
# |8         |Zachary Wilson    |31 |USNS Thompson, FPO AP 63179                            |5687121605           |Hypertension |
# |9         |Rhonda Oconnor    |27 |184 Soto Pines Apt. 875, West Dakota, GA 96278         |275.444.2526         |Asthma       |
# |10        |Leslie Baker      |55 |0476 Jake Locks Suite 921, Lewishaven, MT 10958        |001-172-091-9421x7978|Hypertension |
# |11        |Marissa Carlson   |35 |18331 Mendez Pike, Reidhaven, GA 29116                 |(142)411-2096x8020   |Hypertension |
# |12        |Natalie Espinoza  |25 |56674 Edwards Divide Apt. 010, Kimland, MS 78734       |001-903-137-6800x8908|Hypertension |
# |13        |Thomas Lewis      |69 |2972 Erika Rapid, Knightborough, AK 93261              |297.042.4749         |Hypertension |
# |14        |Jamie Patton      |39 |5790 Gregory Ville Suite 343, Lake Ryanland, NJ 30897  |736.521.3499x896     |Hypertension |
# |15        |Ryan Jacobs       |54 |968 Christopher Fields Suite 713, Bradleyside, MI 11292|+1-465-777-3427x928  |Heart Disease|
# |16        |Edward Spencer    |58 |91342 Lambert Bridge Apt. 578, Allentown, AZ 29340     |518-999-4027         |Diabetes     |
# |17        |Nicholas Lynn     |18 |326 Kimberly Pines, Charleschester, GA 05194           |+1-479-155-5838x704  |Diabetes     |
# |18        |Shane Johnson     |35 |96692 Joseph Plains, Lake Alexander, NV 13222          |+1-261-162-5054x658  |Asthma       |
# |19        |Heather Maldonado |28 |878 Anna Meadows Suite 965, Johnland, SD 96413         |0427516494           |Heart Disease|
# |20        |Kimberly Sutton   |36 |4167 Gilbert Loaf, Lake Traceyville, MA 28891          |863.728.9008x8855    |Asthma       |
# |21        |Kelly Sanchez     |69 |285 Ho Meadows, Davidburgh, LA 22803                   |(482)525-8195x02966  |Diabetes     |
# |22        |Lauren Brown      |41 |092 Miller Shore, Rachelland, NM 38042                 |215.426.2649x5099    |Asthma       |
# |23        |Luis Lambert      |23 |192 Cheryl Court Apt. 188, North Connie, OR 31404      |707-689-2739x37123   |Diabetes     |
# |24        |Jennifer Lin      |41 |9786 Sandy Roads Suite 017, Heatherstad, MN 65581      |069-010-8837         |None         |
# |25        |Stephanie Lin     |37 |581 Tricia Walk Suite 688, Port Loretta, MI 29281      |192.542.1112         |None         |
# |26        |Dana Henson       |56 |504 Terrell River Apt. 416, Coleview, OK 03154         |0002992045           |None         |
# |27        |James Lynch DVM   |65 |USNS Lowe, FPO AP 93039                                |748-073-8675         |Asthma       |
# |28        |Tiffany White     |38 |02040 Jonathan Forest Suite 483, Shawshire, MO 69926   |493-498-5973         |Hypertension |
# |29        |Sarah Jones       |69 |3425 Kelly Knoll, North Brandon, RI 87775              |930-093-1692x6687    |None         |
# |30        |John Johnson      |38 |33582 Holly Overpass Apt. 076, Sharonshire, MS 29668   |844.155.8445x0349    |Hypertension |
# |31        |Mitchell Wells    |85 |12778 Anna Drive, North Barbara, OH 79071              |+1-041-450-7480      |Diabetes     |
# |32        |Drew Lee          |64 |117 Amanda Ranch, Beckerfurt, ND 11340                 |8991036954           |Hypertension |
# |33        |Dr. Sandra Michael|65 |Unit 1087 Box 5462, DPO AA 57006                       |001-544-6701x58523   |Heart Disease|
# |34        |Thomas Gill       |22 |34079 Carmen Rapid, Shieldsport, SC 27003              |001-825-757-9906     |Heart Disease|
# |35        |Rebecca Gutierrez |55 |0465 Rose Meadows, Sethburgh, NE 03639                 |+1-074-010-3565x30422|None         |
# |36        |Steven Thompson   |33 |68911 Walter Mountain, North Gabrielle, DE 84569       |001-638-400-0316x9717|Heart Disease|
# |37        |John Rivera Jr.   |57 |USCGC Murray, FPO AA 80530                             |865.280.9184         |None         |
# |38        |Allen Tyler       |77 |113 Nicolas Isle, West Williamland, NV 85966           |413-536-1375x751     |Diabetes     |
# |39        |Mary Olson        |44 |9799 Gates Place, Jamesshire, GA 87280                 |3617684021           |Diabetes     |
# |40        |Natasha Young     |68 |7885 Garcia Alley Suite 064, Flynnton, SD 92390        |4404906660           |Diabetes     |
# |41        |Cynthia Davidson  |64 |584 Jonathan Radial, New Monicaland, ND 80986          |(279)577-7352        |None         |
# |42        |Sheila Dunn       |74 |479 Judy Walks Apt. 256, Jenniferside, DC 04483        |964.995.7751         |Asthma       |
# |43        |Kenneth Durham    |36 |1692 Stephen Bridge, New Gregory, IN 94855             |001-636-032-7685x399 |Asthma       |
# |44        |Donna Pollard     |67 |5150 Thomas Court, Isaacbury, WI 34094                 |074-596-6478x48298   |Hypertension |
# |45        |Kristen Banks     |57 |52761 Jamie Fields, Reynoldshaven, MN 03951            |(149)007-2291x540    |Diabetes     |
# |46        |Jacob Joyce       |77 |7535 Woods Courts, Katieview, WI 11426                 |001-876-915-3721x8584|Hypertension |
# |47        |Michael Walters   |26 |9936 Hanson Dam, New Lisaside, TX 77908                |(453)734-8599x8652   |Hypertension |
# |48        |Robert Gomez      |67 |8890 Brian Vista, Lake Seanview, CT 14513              |700-465-2048x41730   |Heart Disease|
# |49        |Brittany Parrish  |37 |269 Cory Hills Apt. 071, Lake Ashley, GA 61006         |(969)201-5993x451    |Hypertension |
# |50        |Robin Kramer      |69 |3222 David Land Apt. 889, West Andreatown, NM 40602    |(548)824-0937        |None         |
# +----------+------------------+---+-------------------------------------------------------+---------------------+-------------+
# only showing top 50 rows

# %% [markdown]
# ## Step 2: Data Transformation (Should occur before de-identification)
# Clean and transform the data. Ensure that:
# - Phone numbers and addresses are in a consistent format.
# - Data is deduplicated based on patient_id.
# - Join the two datasets using patient_id to create a single view of the patient and their appointment history.

# %%
from pyspark.sql.functions import regexp_replace, concat_ws, col, when, split, length, count, countDistinct

# Clean the original column to remove non-numeric characters for clarity
patients_df = patients_df.withColumn("phone_number", regexp_replace(col("phone_number"), r"[^0-9x]", ""))

# Split phone_number into core_number and extension
split_col = split(col("phone_number"), "x")
patients_df = patients_df.withColumn("core_number", split_col.getItem(0)) \
                         .withColumn("extension", split_col.getItem(1))

# Strip country code based on the length of core_number
patients_df = patients_df.withColumn(
    "core_number",
    when((length(col("core_number")) == 11), col("core_number").substr(2, 10))
    .when((length(col("core_number")) == 12), col("core_number").substr(3, 10))
    .when((length(col("core_number")) == 13), col("core_number").substr(4, 10))
    .otherwise(col("core_number"))
)

# Recombine core phone number and extension
patients_df = patients_df.withColumn(
    "phone_number",
    when(col("extension") != "", concat_ws("x", col("core_number"), col("extension")))
    .otherwise(col("core_number"))
)

# Drop intermediary columns
patients_df = patients_df.drop("core_number", "extension")

# TODO: MAKE THIS NOT SUCK
# Normalize addresses by removing leading zeroes, extra spaces, and extra commas
patients_df = patients_df.withColumn("address", regexp_replace(col("address"), r"\s+", " ")) \
       .withColumn("address", regexp_replace(col("address"), r",+", ",")) \
       .withColumn("address", regexp_replace(col("address"), r"^0+", ""))
       #.withColumn("address", initcap(trim(col("address")))) \

# Show normalized df
patients_df.show(10, truncate=False)

# No duplicates found in this file, but dupes could be found in future files.
patients_df.select(
    count("patient_id").alias("total_patient_id"),
    countDistinct("patient_id").alias("distinct_patient_id")
).show()

# Drop duplicates based on patient_id
patients_df = patients_df.dropDuplicates(["patient_id"])

# Join patients to appointments and create a view
appointment_history_df = patients_df.join(appointments_df, on="patient_id", how="inner")
appointment_history_df.createOrReplaceTempView("appointment_history")
appointment_history_df.show(10, truncate=False)
# Out:
# +----------+---------------+---+----------------------------------------------------+----------------+------------+
# |patient_id|name           |age|address                                             |phone_number    |diagnosis   |
# +----------+---------------+---+----------------------------------------------------+----------------+------------+
# |1         |Nicole Taylor  |36 |6377 Jennifer Trail Apt. 075, Calebside, NY 22906   |0808983247      |Asthma      |
# |2         |Nathan Dorsey  |46 |56 Thompson Park Suite 212, West Anitaport, NY 11534|2826032670x455  |Asthma      |
# |3         |Jennifer Garcia|61 |792 Mark Wells, Jaclynport, TN 90027                |8614642617x287  |Diabetes    |
# |4         |Joshua Simon   |41 |5655 Harris Inlet, Nealton, MS 89986                |5312690179      |Asthma      |
# |5         |Juan Gallegos  |37 |150 Miranda Unions, Bradburgh, FL 64440             |7719585462x30717|Asthma      |
# |6         |Dawn Holland   |39 |2523 Flores Radial Suite 462, South Hannah, ND 92740|1345643940x037  |None        |
# |7         |Alan Garrison  |79 |3040 Eddie Bypass, Lake Andrew, RI 07138            |5828788103x560  |Diabetes    |
# |8         |Zachary Wilson |31 |USNS Thompson, FPO AP 63179                         |5687121605      |Hypertension|
# |9         |Rhonda Oconnor |27 |184 Soto Pines Apt. 875, West Dakota, GA 96278      |2754442526      |Asthma      |
# |10        |Leslie Baker   |55 |476 Jake Locks Suite 921, Lewishaven, MT 10958      |1720919421x7978 |Hypertension|
# +----------+---------------+---+----------------------------------------------------+----------------+------------+
# only showing top 10 rows
#
# +----------------+-------------------+
# |total_patient_id|distinct_patient_id|
# +----------------+-------------------+
# |            1000|               1000|
# +----------------+-------------------+
#
# +----------+----------------+---+----------------------------------------------------+----------------+------------+----------------+------------------+
# |patient_id|name            |age|address                                             |phone_number    |diagnosis   |appointment_date|doctor            |
# +----------+----------------+---+----------------------------------------------------+----------------+------------+----------------+------------------+
# |3         |Jennifer Garcia |61 |792 Mark Wells, Jaclynport, TN 90027                |8614642617x287  |Diabetes    |2024-05-12      |Kristina Collins  |
# |4         |Joshua Simon    |41 |5655 Harris Inlet, Nealton, MS 89986                |5312690179      |Asthma      |2024-08-17      |Felicia Moore     |
# |5         |Juan Gallegos   |37 |150 Miranda Unions, Bradburgh, FL 64440             |7719585462x30717|Asthma      |2024-05-08      |Jason Taylor      |
# |5         |Juan Gallegos   |37 |150 Miranda Unions, Bradburgh, FL 64440             |7719585462x30717|Asthma      |2024-03-20      |Eugene Wilson MD  |
# |6         |Dawn Holland    |39 |2523 Flores Radial Suite 462, South Hannah, ND 92740|1345643940x037  |None        |2024-08-23      |Jessica Martin    |
# |8         |Zachary Wilson  |31 |USNS Thompson, FPO AP 63179                         |5687121605      |Hypertension|2024-01-18      |Erin Castro       |
# |10        |Leslie Baker    |55 |476 Jake Locks Suite 921, Lewishaven, MT 10958      |1720919421x7978 |Hypertension|2024-09-08      |Mary Ortiz        |
# |11        |Marissa Carlson |35 |18331 Mendez Pike, Reidhaven, GA 29116              |1424112096x8020 |Hypertension|2024-04-17      |Sherri Fitzpatrick|
# |12        |Natalie Espinoza|25 |56674 Edwards Divide Apt. 010, Kimland, MS 78734    |9031376800x8908 |Hypertension|2024-07-04      |Joy Price         |
# |12        |Natalie Espinoza|25 |56674 Edwards Divide Apt. 010, Kimland, MS 78734    |9031376800x8908 |Hypertension|2024-01-03      |Richard Martinez  |
# +----------+----------------+---+----------------------------------------------------+----------------+------------+----------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ## Step 3: De-identification (Should occur after transformation)
# De-identify sensitive patient data such as name, address, and phone_number using an anonymization technique (e.g., hashing).
# Ensure that the data can still be linked across the two datasets via a secure common identifier (e.g., patient_id).

# %%
from pyspark.sql.functions import sha2

# PII columns to hash
pii_columns_patients = ['name', 'address', 'phone_number']

# Hash PII columns in appointment_history dataframe
appointment_history_anon = appointment_history_df.select(
    *[sha2(col, 256).alias(col) if col in pii_columns_patients 
      else col for col in appointment_history_df.columns]
)

print("\nSample of anonymized patients:")
appointment_history_anon.show(10, truncate=True)

# Store these as new dataframes for further analysis
appointment_history_df = appointment_history_anon
print(appointment_history_df.count())
# Out:
# Sample of anonymized patients:
# +----------+--------------------+---+--------------------+--------------------+------------+----------------+------------------+
# |patient_id|                name|age|             address|        phone_number|   diagnosis|appointment_date|            doctor|
# +----------+--------------------+---+--------------------+--------------------+------------+----------------+------------------+
# |         3|9a968bebac0b2fd19...| 61|d9eb2a0b663611b13...|d8f795b1146bd0a98...|    Diabetes|      2024-05-12|  Kristina Collins|
# |         4|f19ee33dad5f31ec1...| 41|c0ed2953fbb1e7e53...|fe72aeb66c14c151b...|      Asthma|      2024-08-17|     Felicia Moore|
# |         5|12b5e6c34b4527272...| 37|c65ddb9070d9568f1...|6c821939cf5c983be...|      Asthma|      2024-05-08|      Jason Taylor|
# |         5|12b5e6c34b4527272...| 37|c65ddb9070d9568f1...|6c821939cf5c983be...|      Asthma|      2024-03-20|  Eugene Wilson MD|
# |         6|287946ab5d3399cbd...| 39|916c39d5b4b7d5cb0...|8c55e84c66abe2cc7...|        None|      2024-08-23|    Jessica Martin|
# |         8|bf2c933f110119cc6...| 31|7554527f2ecaef5b8...|016d54bd44391462c...|Hypertension|      2024-01-18|       Erin Castro|
# |        10|f750f40752f2afab4...| 55|aeff4591a80b2ab54...|7aaec80cd05695dd1...|Hypertension|      2024-09-08|        Mary Ortiz|
# |        11|ce5a94822cad1d9ef...| 35|aacdd7769d560685a...|be0d7922660879ce3...|Hypertension|      2024-04-17|Sherri Fitzpatrick|
# |        12|8b57eb2774bc66447...| 25|c42bfeeeb3af14f08...|bb617d27a46842ef6...|Hypertension|      2024-07-04|         Joy Price|
# |        12|8b57eb2774bc66447...| 25|c42bfeeeb3af14f08...|bb617d27a46842ef6...|Hypertension|      2024-01-03|  Richard Martinez|
# +----------+--------------------+---+--------------------+--------------------+------------+----------------+------------------+
# only showing top 10 rows
#
# 1000

# %% [markdown]
# ## Step 4: Data Storage
# - Set up LocalStack to simulate an S3 environment.
# - Store the de-identified and transformed data as Parquet files in the LocalStack S3 bucket.
# - Ensure your solution uses Docker to run the pipeline in a containerized environment.

# %%
import requests

# Test connection to LocalStack S3 service
url = "http://localstack:4566"
try:
    response = requests.get(url)
    if response.status_code == 200:
        print("Successfully connected to LocalStack:", response.text)
    else:
        print("Failed to connect to LocalStack. Status code:", response.status_code)
except requests.exceptions.RequestException as e:
    print("Error connecting to LocalStack:", e)
# Out:
# Successfully connected to LocalStack:

# %%
import boto3

# Connect to LocalStack S3
s3 = boto3.client(
    "s3",
    endpoint_url="http://localstack:4566",
    aws_access_key_id="test",
    aws_secret_access_key="test",
    region_name="us-east-1"
)

# Create the bucket
bucket_name = "my-test-bucket"
try:
    s3.create_bucket(Bucket=bucket_name)
    print(f"Bucket '{bucket_name}' created successfully.")
except Exception as e:
    print("Error creating bucket:", e)
# Out:
# Bucket 'my-test-bucket' created successfully.

# %%
import shutil
import os

# Local directory where the files are stored
local_temp_path = "/tmp/data/appointment_history.parquet"

# Delete everything in tmp
if os.path.exists("/tmp/data/"):
    shutil.rmtree("/tmp/data/")

# Write appointment history to tmp folder as parquet
appointment_history_df.write.parquet(local_temp_path, mode='overwrite')

# Get the list of parquet part files (excluding any meta files like .crc)
parquet_files = [f for f in os.listdir(local_temp_path) if f.endswith('.parquet')]

# Upload each part file to S3
for part_file in parquet_files:
    part_file_path = os.path.join(local_temp_path, part_file)
    s3_key = f"{part_file}"  # Use a dynamic key, such as a folder with the filename

    # Upload the part file to S3
    s3.upload_file(part_file_path, bucket_name, s3_key)
    print(f"Uploaded {part_file} to S3 bucket '{bucket_name}' with key '{s3_key}'.")

print(f"All part files have been successfully uploaded to S3 bucket '{bucket_name}'.")
# Out:
# Uploaded part-00000-65e94d3f-4118-46a4-a9ce-b79bbae62fe2-c000.snappy.parquet to S3 bucket 'my-test-bucket' with key 'part-00000-65e94d3f-4118-46a4-a9ce-b79bbae62fe2-c000.snappy.parquet'.
# All part files have been successfully uploaded to S3 bucket 'my-test-bucket'.

# %% [markdown]
# ## Step 5: Data Join with PySpark
# - Use PySpark to load the two Parquet tables (patient data and appointment data) from the LocalStack S3 bucket.
# - Join the two tables on patient_id and print the resulting joined dataset.

# %%
# Data is already joined, pulling down from Localstack bucket and displaying...

# List all files in the S3 bucket
response = s3.list_objects_v2(Bucket=bucket_name)

# Filter the list of files to only include Parquet files
parquet_files = [obj['Key'] for obj in response.get('Contents', []) if obj['Key'].endswith('.parquet')]

# Temporary directory to store the files
temp_dir = '/tmp/parquet_files'

# Ensure the directory exists
os.makedirs(temp_dir, exist_ok=True)

# Download each Parquet file from S3 and save it locally
for file_key in parquet_files:
    # Download the file
    file_obj = s3.get_object(Bucket=bucket_name, Key=file_key)
    file_data = file_obj['Body'].read()
    
    # Write the file data to a local file
    local_path = os.path.join(temp_dir, os.path.basename(file_key))
    with open(local_path, 'wb') as f:
        f.write(file_data)

# Now read all the Parquet files from the local directory into a single Spark DataFrame
df = spark.read.parquet(temp_dir)

# Show the DataFrame
df.show()
print(df.count())
df.select("patient_id").where("patient_id = 3").show()
# Out:
# +----------+--------------------+---+--------------------+--------------------+-------------+----------------+------------------+
# |patient_id|                name|age|             address|        phone_number|    diagnosis|appointment_date|            doctor|
# +----------+--------------------+---+--------------------+--------------------+-------------+----------------+------------------+
# |         3|9a968bebac0b2fd19...| 61|d9eb2a0b663611b13...|d8f795b1146bd0a98...|     Diabetes|      2024-05-12|  Kristina Collins|
# |         4|f19ee33dad5f31ec1...| 41|c0ed2953fbb1e7e53...|fe72aeb66c14c151b...|       Asthma|      2024-08-17|     Felicia Moore|
# |         5|12b5e6c34b4527272...| 37|c65ddb9070d9568f1...|6c821939cf5c983be...|       Asthma|      2024-05-08|      Jason Taylor|
# |         5|12b5e6c34b4527272...| 37|c65ddb9070d9568f1...|6c821939cf5c983be...|       Asthma|      2024-03-20|  Eugene Wilson MD|
# |         6|287946ab5d3399cbd...| 39|916c39d5b4b7d5cb0...|8c55e84c66abe2cc7...|         None|      2024-08-23|    Jessica Martin|
# |         8|bf2c933f110119cc6...| 31|7554527f2ecaef5b8...|016d54bd44391462c...| Hypertension|      2024-01-18|       Erin Castro|
# |        10|f750f40752f2afab4...| 55|aeff4591a80b2ab54...|7aaec80cd05695dd1...| Hypertension|      2024-09-08|        Mary Ortiz|
# |        11|ce5a94822cad1d9ef...| 35|aacdd7769d560685a...|be0d7922660879ce3...| Hypertension|      2024-04-17|Sherri Fitzpatrick|
# |        12|8b57eb2774bc66447...| 25|c42bfeeeb3af14f08...|bb617d27a46842ef6...| Hypertension|      2024-07-04|         Joy Price|
# |        12|8b57eb2774bc66447...| 25|c42bfeeeb3af14f08...|bb617d27a46842ef6...| Hypertension|      2024-01-03|  Richard Martinez|
# |        16|b6f3d9f97812fcf45...| 58|5e2508d891cdf23ff...|1fd518f856128bdfe...|     Diabetes|      2024-04-26|        Stacy Leon|
# |        17|f848f46e14285ee56...| 18|74e333a77c7bb1ee3...|6d2ca28eaf1987847...|     Diabetes|      2024-07-02|  Joshua Rodriguez|
# |        17|f848f46e14285ee56...| 18|74e333a77c7bb1ee3...|6d2ca28eaf1987847...|     Diabetes|      2024-04-06|        Ryan Davis|
# |        17|f848f46e14285ee56...| 18|74e333a77c7bb1ee3...|6d2ca28eaf1987847...|     Diabetes|      2024-08-24|  Cheyenne Watkins|
# |        18|e9a54ed7545d579ce...| 35|cac3c6e128b13f0e9...|06f9fec78a014d393...|       Asthma|      2024-06-26|    Matthew Lawson|
# |        18|e9a54ed7545d579ce...| 35|cac3c6e128b13f0e9...|06f9fec78a014d393...|       Asthma|      2024-03-29|  Kristine Robbins|
# |        19|e443469aede86e2b6...| 28|f1e5d98553b67b197...|368f937838ed72eff...|Heart Disease|      2024-01-08|      Julia Lawson|
# |        20|9556755a30fab6e92...| 36|ffdbbf7d38bf56b61...|300a8b97c84da42e4...|       Asthma|      2024-04-30|        Rose Bruce|
# |        20|9556755a30fab6e92...| 36|ffdbbf7d38bf56b61...|300a8b97c84da42e4...|       Asthma|      2024-03-27|       Becky Scott|
# |        21|3fce21e62bb92689e...| 69|18c9fdf1f7e5f3b2f...|6698d174929be7bcc...|     Diabetes|      2024-04-21|     Sonya Goodman|
# +----------+--------------------+---+--------------------+--------------------+-------------+----------------+------------------+
# only showing top 20 rows
#
# 5000
# +----------+
# |patient_id|
# +----------+
# |         3|
# |         3|
# |         3|
# |         3|
# |         3|
# +----------+
